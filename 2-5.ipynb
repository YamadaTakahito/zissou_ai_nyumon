# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn import preprocessing

# %%
X = np.zeros((20, 2))
X[0:10, 1] = range(0, 10)
X[10:20, 1] = range(0, 10)
X[0, 0] = 1.0
X[9, 0] = 1.0
X[1:9, 0] = 3.0
X[10:20, 0] = range(-1, -11, -1)
X[9, 0] = 1
X[19, 0] = -1

y = np.zeros((20))
y[10:20] = 1.0
y = y.astype(np.int8)

plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm)
plt.show()

# %%
from mlxtend.plotting import plot_decision_regions
sc = preprocessing.StandardScaler()
sc.fit(X)
X_std = sc.transform(X)
lr = LogisticRegression(random_state=0)
lr.fit(X_std, y)
plot_decision_regions(X_std, y, clf=lr)
# Out:
# <Axes: >

# %%
from sklearn import svm
clf = svm.LinearSVC(random_state=0)
clf.fit(X_std, y)
plot_decision_regions(X_std, y, clf=clf)
# Out:
# /Users/yamada/.pyenv/versions/3.11.3/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# <Axes: >

# %%
X[19, 0] = 2
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.coolwarm)
plt.show()

# %%
sc = preprocessing.StandardScaler()
sc.fit(X)
X_std = sc.transform(X)
clf = svm.LinearSVC(random_state=0)
clf.fit(X_std, y)
plot_decision_regions(X_std, y, clf=clf)
# Out:
# /Users/yamada/.pyenv/versions/3.11.3/lib/python3.11/site-packages/sklearn/svm/_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# <Axes: >
